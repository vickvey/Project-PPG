# %%
import pandas as pd

# %%
features_df = pd.read_csv('Datasets/features.csv')
labels_df = pd.read_csv('Datasets/labels.csv')

# %%
features_df.shape
# Out:
# (102, 93)

# %%
labels_df.shape
# Out:
# (110, 2)

# %%
# Merge on the basis of 'P_Id'
data = pd.merge(features_df, labels_df, on='P_Id')

# %%
data.head()
# Out:
#    P_Id  PPG_Rate_Mean  HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  \
# 0   101      72.160656  838.787356  161.144697         NaN         NaN
# 1   102      94.333514  648.155039  196.751139    29.61793  192.373443
# 2   103      91.269287  673.426396  240.470162         NaN         NaN
# 3   104      76.862836  800.455621  295.652405         NaN         NaN
# 4   105      68.409940  918.483221  655.450522         NaN         NaN
#
#    HRV_SDANN2  HRV_SDNNI2  HRV_SDANN5  HRV_SDNNI5  ...  HRV_ShanEn  \
# 0         NaN         NaN         NaN         NaN  ...    7.103751
# 1         NaN         NaN         NaN         NaN  ...    7.555224
# 2         NaN         NaN         NaN         NaN  ...    7.316140
# 3         NaN         NaN         NaN         NaN  ...    7.143425
# 4         NaN         NaN         NaN         NaN  ...    7.084940
#
#    HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD   HRV_HFD   HRV_KFD  \
# 0     1.291662  1.229793   1.392336    1.912396  1.691472  1.965384  4.166548
# 1     1.371911  1.174007   1.288954    1.839586  1.707419  1.967041  2.788036
# 2     1.471038  1.387296   1.315389    1.876066  1.833765  1.939231  4.690344
# 3     1.156025  1.196983   1.302091    1.612782  1.572197  1.974733  2.787734
# 4     1.133012  1.458232   1.302750    1.426864  1.427651  1.984928  2.193969
#
#     HRV_LZC  anxiety_meter
# 0  1.197715            7.0
# 1  1.117846           16.0
# 2  1.122028           10.0
# 3  1.051012            8.0
# 4  1.162819           15.0
#
# [5 rows x 94 columns]

# %%
def count_missing_values(df):
    """Count missing values in a DataFrame
    
    Args:
        df (pd.DataFrame): DataFrame for which to count missing values
        
    Returns:
        dict: A dictionary containing the count of missing values for each column with at least one missing value
    """
    missing_values = df.isna().sum()
    # Filter out columns with zero missing values
    missing_values = missing_values[missing_values > 0]
    return missing_values.to_dict()

# %%
missing_data_info = count_missing_values(data)

# %%
missing_data_info
# Out:
# {'HRV_SDANN1': 75,
#  'HRV_SDNNI1': 75,
#  'HRV_SDANN2': 101,
#  'HRV_SDNNI2': 101,
#  'HRV_SDANN5': 101,
#  'HRV_SDNNI5': 101,
#  'HRV_ULF': 101,
#  'HRV_VLF': 51,
#  'HRV_DFA_alpha2': 7,
#  'HRV_MFDFA_alpha2_Width': 7,
#  'HRV_MFDFA_alpha2_Peak': 7,
#  'HRV_MFDFA_alpha2_Mean': 7,
#  'HRV_MFDFA_alpha2_Max': 7,
#  'HRV_MFDFA_alpha2_Delta': 7,
#  'HRV_MFDFA_alpha2_Asymmetry': 7,
#  'HRV_MFDFA_alpha2_Fluctuation': 7,
#  'HRV_MFDFA_alpha2_Increment': 7}

# %%
# Remove columns with more than 20 missing values
missing_cols_to_remove = [col for col, count in missing_data_info.items() if count > 20]

# %%
missing_cols_to_remove
# Out:
# ['HRV_SDANN1',
#  'HRV_SDNNI1',
#  'HRV_SDANN2',
#  'HRV_SDNNI2',
#  'HRV_SDANN5',
#  'HRV_SDNNI5',
#  'HRV_ULF',
#  'HRV_VLF']

# %%
data = data.drop(columns=missing_cols_to_remove)

# %%
data.shape
# Out:
# (101, 86)

# %%
X = data.drop('anxiety_meter', axis=1)
y = data['anxiety_meter']

# %%
X
# Out:
#      P_Id  PPG_Rate_Mean  HRV_MeanNN    HRV_SDNN   HRV_RMSSD    HRV_SDSD  \
# 0     101      72.160656  838.787356  161.144697  216.334225  216.962029
# 1     102      94.333514  648.155039  196.751139  269.605729  270.131772
# 2     103      91.269287  673.426396  240.470162  313.700844  314.500938
# 3     104      76.862836  800.455621  295.652405  419.562698  420.816766
# 4     105      68.409940  918.483221  655.450522  920.360670  923.485198
# ..    ...            ...         ...         ...         ...         ...
# 96    215     106.643368  570.586957  199.166962  245.539186  246.212727
# 97    216      88.979798  691.214286  429.343966  515.791973  517.634875
# 98    217     109.566313  553.231834  155.993383  196.165914  196.496027
# 99    218     126.073719  478.073171  112.120465  133.252377  133.476196
# 100   219      95.685516  627.864629   66.593056   69.632179   69.785340
#
#      HRV_CVNN  HRV_CVSD  HRV_MedianNN  HRV_MadNN  ...  HRV_SampEn  HRV_ShanEn  \
# 0    0.192116  0.257913         853.5   106.0059  ...    1.662548    7.103751
# 1    0.303556  0.415959         636.5   152.7078  ...    1.868132    7.555224
# 2    0.357085  0.465828         609.0   203.1162  ...    1.746639    7.316140
# 3    0.369355  0.524155         744.0   182.3598  ...    1.377711    7.143425
# 4    0.713623  1.002044         776.0   324.6894  ...    1.668343    7.084940
# ..        ...       ...           ...        ...  ...         ...         ...
# 96   0.349056  0.430327         501.5    64.4931  ...    0.678190    6.976664
# 97   0.621145  0.746211         550.5   123.7971  ...    0.770202    6.889927
# 98   0.281967  0.354582         500.0    50.4084  ...    0.805586    7.184780
# 99   0.234526  0.278728         456.0    34.8411  ...    0.744972    6.726446
# 100  0.106063  0.110903         631.0    59.3040  ...    1.528139    6.962487
#
#      HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD   HRV_HFD  \
# 0       1.291662  1.229793   1.392336    1.912396  1.691472  1.965384
# 1       1.371911  1.174007   1.288954    1.839586  1.707419  1.967041
# 2       1.471038  1.387296   1.315389    1.876066  1.833765  1.939231
# 3       1.156025  1.196983   1.302091    1.612782  1.572197  1.974733
# 4       1.133012  1.458232   1.302750    1.426864  1.427651  1.984928
# ..           ...       ...        ...         ...       ...       ...
# 96      0.903258  1.056822   1.177499    1.092981  1.148055  1.907768
# 97      0.857505  0.837755   1.038622    0.956516  0.913066  1.897684
# 98      0.775767  0.978753   1.191947    1.138375  1.145786  1.932554
# 99      0.600827  0.474042   1.009792    0.961145  0.984105  1.917123
# 100     1.048252  1.326621   1.389550    1.960139  1.643144  1.857610
#
#       HRV_KFD   HRV_LZC
# 0    4.166548  1.197715
# 1    2.788036  1.117846
# 2    4.690344  1.122028
# 3    2.787734  1.051012
# 4    2.193969  1.162819
# ..        ...       ...
# 96   2.744730  0.736001
# 97   1.796485  1.018469
# 98   2.855720  0.763747
# 99   1.941572  0.839453
# 100  2.694537  0.890041
#
# [101 rows x 85 columns]
